# %%
import random

min = 20
max = 30
target = random.randint(min,max)
print("=============猜數字遊戲==============\n")
print(f"猜數字的範圍:{min}~{max}")
print(target)

# %%
#加入次數計算
import random

min = 1
max = 2
count = 0
target = random.randint(min,max)
print("=============猜數字遊戲==============\n")
print(f"猜數字的範圍:{min}~{max}")

while(True):
    keyin = int(input(f"猜數字範圍:{min}~{max}:"))
    count += 1
    if keyin == target:
        print("ㄟ黑bingo答對了,答案是:",target)
        print(f"您總共猜了{count}次")
        break
    else:
        print("猜錯了")
        print(f"您已經猜了{count}次")

print("遊戲結束:))")

# %%
#加入判斷輸入錯誤之指令
import random

min = 1
max = 10
count = 0
target = random.randint(min,max)
print("==============猜數字遊戲==================\n")

while(True):
    try:
        keyin = int(input(f"猜數字範圍:{min}~{max}:"))
    except:
        print("輸入格式錯誤")
        count += 1
        print(f"您已經猜了{count}次")
    else:
        count += 1
        if keyin == target:
            print(f"賓果!猜對了, 答案是:",target)
            print(f"您總共猜了{count}次")
            break
        else:
            print("猜錯了")
            print(f"您已經猜了{count}次")

print("遊戲結束")

# %%
#加入:提示不在範圍內的值
import random

min = 1
max = 5
count = 0
target = random.randint(min,max)
print("==============猜數字遊戲==================\n")

while(True):
    try:
        keyin = int(input(f"猜數字範圍:{min}~{max}:"))
    except:
        print("輸入格式錯誤")
        count += 1
        print(f"您已經猜了{count}次")
    else:
        count += 1
        if(keyin >= min and keyin <= max):
            if keyin == target:
                print(f"賓果!猜對了, 答案是:",target)
                print(f"您總共猜了{count}次")
                break
            else:
                print("猜錯了")
                print(f"您已經猜了{count}次")
        else:
            print("輸入錯誤,超出範圍")
            print(f"您已經猜了{count}次")

print("遊戲結束")

# %%
#最終加入範圍提示

import random

min = 1
max = 100
count = 0
target = random.randint(min,max)
print("==============猜數字遊戲==================\n")

while(True):
    try:
        keyin = int(input(f"猜數字範圍:{min}~{max}:"))
    except:
        print("輸入格式錯誤")
        count += 1
        print(f"您已經猜了{count}次")
    else:
        count += 1
        if(keyin >= min and keyin <= max):
            if keyin == target:
                print(f"賓果!猜對了, 答案是:",target)
                print(f"您總共猜了{count}次")
                break
            elif keyin > target:
                print("再小一點")
                max = keyin - 1                
            elif keyin < target:
                print("再大一點")
                min = keyin + 1

            print(f"您已經猜了{count}次")
        else:
            print("輸入錯誤,超出範圍")
            print(f"您已經猜了{count}次")

print("遊戲結束")
